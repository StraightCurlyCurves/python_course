# %% [markdown]
# ## Plotting
#
# To plot something, we need data. For a simple plot, we need the data for the x-axis (for example time, distance, ...) and the y-axis (temparature, ...).
#
# Let's create a minimal example:

# %%
import matplotlib.pyplot as plt
import numpy as np

x_data = np.array([0, 1, 2, 3,  4,  5])
y_data = np.array([0, 1, 4, 9, 16, 25])

plt.plot(x_data, y_data)

# %% [markdown]
# As you can see, this is a simple plot of the square function.
#
# Try to plot the square function from -1000 to 1000 and 11 data points in total. Use the `linspace()` function to generate the x data and _calculate_ the y data!

# %%
# your code here

# %% [markdown]
# The reason why the curve looks bumpy is because we don't have enough data points! We can visualize the actual data points by adding a string parameter:

# %%
plt.plot(x_data, y_data, 'o')

# %% [markdown]
# What is a good sample size to get a smooth curve?

# %% [markdown]
# ## Adding labels
#
# Let's add some labels!

# %%
plt.plot(x_data, y_data)
plt.title('y = x^2')
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.show()

# %% [markdown]
# ## Proper way to use matplotlib  is with figures and axes!
#
# While pyplot functions in Matplotlib, such as plt.plot(), plt.grid(), plt.xlabel(), etc., provide a simple and quick way to create plots, they are not always the best choice for more complex visualizations. This is because pyplot functions operate on a global state, which can lead to less control and flexibility over the plot elements.
#
# Instead, you should use Axes methods for the following reasons:
#
# - Better Control: Using Axes objects allows you to have more precise control over each individual plot element. You can create multiple subplots and customize each one independently.
#
# - Object-Oriented Approach: The Axes methods follow an object-oriented approach, which is more consistent with modern programming practices. This makes the code more readable and maintainable.
#
# - Avoiding Global State: pyplot functions modify a global state, which can lead to unexpected behavior, especially when creating multiple plots in the same script. Using Axes objects avoids this issue by encapsulating the state within the object.
#
# - Enhanced Functionality: The Axes class provides a richer set of methods and properties compared to pyplot functions, enabling more advanced customization and interaction with the plot.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create data
x_data = np.linspace(0, 10, 1000)
y_data = np.sin(2 * np.pi * 3 * x_data) * np.exp(-0.3 * x_data)

# Create a figure and an axes
fig, ax = plt.subplots()

# Plot data on the axes
ax.plot(x_data, y_data)

# Set grid
ax.grid(True)

# Set labels and title
ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_title('Simple Plot')

# Show the plot
plt.show()

# %% [markdown]
# Play around with `figsize` and `dpi`!

# %%
fig, ax = plt.subplots(figsize=(10,10), dpi=100)
x_data = np.linspace(0, 2, 100)
ax.plot(x_data, x_data**2, label='y = x^2')
ax.plot(x_data**2, x_data, label='x = y^2')
ax.legend()
ax.grid(True)
ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_title('Simple Plot')
ax.set_aspect('equal')

plt.show()

# %% [markdown]
# ## Multiple Plots
#
# If labels overlap, use tight layout to fix it.

# %%
import matplotlib.pyplot as plt
import numpy as np

plot_size = 4
dpi = 150

x_data = np.linspace(0, 2, 1000)
freq = 2
y_data_orig = 0.5 * np.sin(2 * np.pi * freq * x_data)

shape = (3, 4)
delta_phi = 180 / (shape[1] - 1) * np.pi / 180
delta_freq = 1
fig, axs = plt.subplots(shape[0], shape[1] , figsize=(plot_size*shape[1],plot_size*shape[0]), dpi=dpi)

for i, ax in enumerate(axs.flat):
    phase_shift = i % shape[1] * delta_phi
    freq_shift = i // shape[1] * delta_freq

    y_data = 0.5 * np.sin(2 * np.pi * (freq + freq_shift) * x_data + phase_shift)

    ax.plot(x_data, y_data_orig, label=f'original')
    ax.plot(x_data, y_data, label=f'modified') # {i * delta_phi * 180 / np.pi:.2f}
    ax.plot(x_data, y_data_orig + y_data, label=f'sum') # {i * delta_freq:.2f}')
    ax.legend()
    ax.grid(True)
    ax.set_xlabel('X Label')
    ax.set_ylabel('Y Label')
    ax.set_title(f'Frequency: {freq + freq_shift} Hz, Phase: {phase_shift * 180 / np.pi:.2f}°')
    ax.set_aspect('equal')
    ax.set_ylim(-1, 1)

# plt.tight_layout()
plt.show()

# %% [markdown]
# ## Interactive plots with ipywidgets (only in Jupyter Notebook)

# %%
import matplotlib.pyplot as plt
import numpy as np

import ipywidgets as widgets
from ipywidgets import interact

x_data = np.linspace(0, 2, 1000)

shape = (3, 4)
delta_phi = 180 / (shape[1] - 1) * np.pi / 180
delta_freq = 1

def plot_interactive(freq, freq_shift, phase_shift):
    fig, ax = plt.subplots(figsize=(10, 6), dpi=100)
    y_data_orig = 0.5 * np.sin(2 * np.pi * freq * x_data)
    y_data = 0.5 * np.sin(2 * np.pi * (freq + freq_shift) * x_data + phase_shift)
    ax.plot(x_data, y_data_orig, label='original')
    ax.plot(x_data, y_data, label=f'modified')
    ax.plot(x_data, y_data_orig + y_data, label='sum')
    ax.legend()
    ax.grid(True)
    ax.set_xlabel('X Label')
    ax.set_ylabel('Y Label')
    ax.set_title(f'Frequency: {freq + freq_shift} Hz, Phase: {phase_shift * 180 / np.pi:.2f}°')
    ax.set_ylim(-1, 1)
    plt.show()

freq = widgets.FloatSlider(min=1, max=10, step=0.1, value=0)
freq_shift = widgets.FloatSlider(min=0, max=5, step=0.1, value=0)
phase_shift = widgets.FloatSlider(min=0, max=2*np.pi, step=np.pi/20, value=0)

interact(plot_interactive, freq=freq, freq_shift=freq_shift, phase_shift=phase_shift)

# %% [markdown]
# ## Boxplot

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate some random data
np.random.seed(10)
data = [np.random.normal(0, std, 100) for std in range(1, 4)]

# Create a figure with specific size and resolution
fig, ax = plt.subplots(figsize=(5, 5), dpi=100)

# Create a boxplot
ax.boxplot(data, tick_labels=['A', 'B', 'C'])

# Set labels and title
ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_title('Boxplot Example')

# %% [markdown]
# ## Histogram

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate some random data
data = np.random.randn(1000)

# Create a figure and an axes
fig, ax = plt.subplots(figsize=(10, 6))

# Create a histogram
ax.hist(data, bins=30, edgecolor='black')

# Set labels and title
ax.set_xlabel('Value')
ax.set_ylabel('Frequency')
ax.set_title('Histogram Example')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# make data: correlated + noise
np.random.seed(1)
x = np.random.randn(5000)
y = x + np.random.randn(5000) / 3

# plot:
fig, ax = plt.subplots()

ax.hist2d(x, y, bins=(np.arange(-3, 3, 0.1), np.arange(-3, 3, 0.1)))

# ax.set(xlim=(-2, 2), ylim=(-3, 3))
ax.set_aspect('equal')

plt.show()

# %% [markdown]
# ## Pie

# %%
import matplotlib.pyplot as plt

# Data for the pie chart
labels = ['A', 'B', 'C', 'D']
sizes = [15, 30, 45, 10]
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']
explode = (0.1, 0, 0, 0)  # explode the 1st slice

# Create a figure and an axes
fig, ax = plt.subplots(figsize=(8, 8))

# Create a pie chart
ax.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=False, startangle=140)

# Set title
ax.set_title('Pie Chart Example')

# Show the plot
plt.show()

# %% [markdown]
# ## Scatter

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate some random data
x = np.linspace(0, 10, 100)
y = 0.5 * x + np.random.normal(0, 1, 100)

# Create a figure and an axes
fig, ax = plt.subplots(figsize=(10, 6))

# Create a scatter plot
ax.scatter(x, y, c='blue', alpha=0.5)

# Set labels and title
ax.set_xlabel('X Value')
ax.set_ylabel('Y Value')
ax.set_title('Scatter Plot Example')

# Show the plot
plt.show()

# %% [markdown]
# ## Bar

# %%
import matplotlib.pyplot as plt

# Data for the bar chart
categories = ['A', 'B', 'C', 'D']
values = [3, 7, 5, 2]

# Create a figure and an axes
fig, ax = plt.subplots(figsize=(10, 6))

# Create a bar chart
ax.bar(categories, values, color='blue')

# Set labels and title
ax.set_xlabel('Category')
ax.set_ylabel('Value')
ax.set_title('Bar Chart Example')

# Show the plot
plt.show()
